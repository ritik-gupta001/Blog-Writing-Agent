# %%
from langchain_community.tools.tavily_search import TavilySearchResults
from dotenv import load_dotenv
load_dotenv()
# Out:
# C:\Users\ritik\AppData\Local\Temp\ipykernel_10768\1690773881.py:1: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.tools.tavily_search import TavilySearchResults
# True

# %%
tool = TavilySearchResults(max_results=2)
results = tool.invoke({"query": 'ChatGPT version releases and updates from 2022 to 2026'})
results
# Out:
# C:\Users\ritik\AppData\Local\Temp\ipykernel_10768\1187185310.py:1: LangChainDeprecationWarning: The class `TavilySearchResults` was deprecated in LangChain 0.3.25 and will be removed in 1.0. An updated version of the class exists in the `langchain-tavily package and should be used instead. To use it run `pip install -U `langchain-tavily` and import as `from `langchain_tavily import TavilySearch``.
#   tool = TavilySearchResults(max_results=2)
# [{'title': 'ChatGPT - Wikipedia',
#   'url': 'https://en.wikipedia.org/wiki/ChatGPT',
#   'content': 'Wikipedia\nThe Free Encyclopedia\n\n## Contents\n\n# ChatGPT\n\nPage semi-protected\n\n| ChatGPT | |\n --- |\n|  | |\n| Developer | OpenAI |\n| Initial release | November 30, 2022 (3 years ago) (2022-11-30) |\n|  | |\n| Stable release | May 21, 2026 (21 days ago) (2026-05-21) |\n|  | |\n| Engine | GPT-5.5 |\n| Platform | Cloud computing platforms |\n| Available in | 59 languages |\n| Type |  Chatbot  Large language model  Generative pre-trained transformer |\n| License | Proprietary service |\n| Website | chatgpt.com |\n\n|  |',
#   'score': 0.94289196},
#  {'title': 'ChatGPT Version History – Features and Updates - Objects',
#   'url': 'https://objects.ws/blog/chatgpt-version-history',
#   'content': 'ChatGPT VersionsRelease DateCrucial Features\nChatGPT 5.5 April 2026 The latest version prioritizes reasoning, agentic coding, deep research, and computer use (autonomous navigation of interfaces).\nChatGPT 5.4 March 2026 This version valued reasoning, agentic workflows, and coding. Users were able to perform crucial tasks, such as deep web search. Moreover, it helped maintain context more effectively for queries that usually required detailed thinking.\nChatGPT 5.3 GPT-5.3-Codex was launched in February 2026. GPT-5.3 Instant was introduced in March 2026.This version was handy for enhancing full-cycle software development along with collaboration. It also delighted users through more accurate, logical answers. [...] ChatGPT 5.2 December 2025 The version, GPT-5.2, favored routine activities and learning. Users were allowed to ask technical questions in a conversational tone.\nChatGPT 5.1 November 2025 Answers have become smarter and conversational. GPT-5.1 Instant and GPT 5.1 Thinking were launched to provide users with more simplified and precise responses.\nChatGPT 5August 2025 GPT-5 demonstrated tool coordination, context management, and improved reasoning.\nChatGPT Agent July 2025 ChatGPT Agent helped users manage their tasks. It worked as a combination of Operator, Codex, and Deep Research.\nOpenAI o3 and o4-mini Launch April 2025 These models provided enhanced reasoning capabilities. [...] ## What is GPT-5.2?\n\nGPT-5.2 officially came to market on December 11, 2025. This version supported beginners, experienced professionals, and other users. GPT-5.2 Instant, the advanced model, was beneficial for routine activities and learning. This version benefited professionals who wanted to learn and seek answers to technical questions, presented in a conversational tone.\n\n## What is GPT-5.1?\n\nGPT-5.1’s release date was November 12, 2025. GPT-5 was upgraded to GPT-5.1 Instant and GPT-5.1 Thinking. It helped users ask complex, detailed questions to GPT-5.1 Instant and instantly receive answers, as it smartly used light adaptive reasoning. Likewise, GPT-5.1 Thinking valued thinking time to offer simple, clear responses to demanding tasks.',
#   'score': 0.92995757}]

# %%
for r in results:
    print(r['content'])
# Out:
# Wikipedia
# The Free Encyclopedia
#
# ## Contents
#
# # ChatGPT
#
# Page semi-protected
#
# | ChatGPT | |
#  --- |
# |  | |
# | Developer | OpenAI |
# | Initial release | November 30, 2022 (3 years ago) (2022-11-30) |
# |  | |
# | Stable release | May 21, 2026 (21 days ago) (2026-05-21) |
# |  | |
# | Engine | GPT-5.5 |
# | Platform | Cloud computing platforms |
# | Available in | 59 languages |
# | Type |  Chatbot  Large language model  Generative pre-trained transformer |
# | License | Proprietary service |
# | Website | chatgpt.com |
#
# |  |
# ChatGPT VersionsRelease DateCrucial Features
# ChatGPT 5.5 April 2026 The latest version prioritizes reasoning, agentic coding, deep research, and computer use (autonomous navigation of interfaces).
# ChatGPT 5.4 March 2026 This version valued reasoning, agentic workflows, and coding. Users were able to perform crucial tasks, such as deep web search. Moreover, it helped maintain context more effectively for queries that usually required detailed thinking.
# ChatGPT 5.3 GPT-5.3-Codex was launched in February 2026. GPT-5.3 Instant was introduced in March 2026.This version was handy for enhancing full-cycle software development along with collaboration. It also delighted users through more accurate, logical answers. [...] ChatGPT 5.2 December 2025 The version, GPT-5.2, favored routine activities and learning. Users were allowed to ask technical questions in a conversational tone.
# ChatGPT 5.1 November 2025 Answers have become smarter and conversational. GPT-5.1 Instant and GPT 5.1 Thinking were launched to provide users with more simplified and precise responses.
# ChatGPT 5August 2025 GPT-5 demonstrated tool coordination, context management, and improved reasoning.
# ChatGPT Agent July 2025 ChatGPT Agent helped users manage their tasks. It worked as a combination of Operator, Codex, and Deep Research.
# OpenAI o3 and o4-mini Launch April 2025 These models provided enhanced reasoning capabilities. [...] ## What is GPT-5.2?
#
# GPT-5.2 officially came to market on December 11, 2025. This version supported beginners, experienced professionals, and other users. GPT-5.2 Instant, the advanced model, was beneficial for routine activities and learning. This version benefited professionals who wanted to learn and seek answers to technical questions, presented in a conversational tone.
#
# ## What is GPT-5.1?
#
# GPT-5.1’s release date was November 12, 2025. GPT-5 was upgraded to GPT-5.1 Instant and GPT-5.1 Thinking. It helped users ask complex, detailed questions to GPT-5.1 Instant and instantly receive answers, as it smartly used light adaptive reasoning. Likewise, GPT-5.1 Thinking valued thinking time to offer simple, clear responses to demanding tasks.
